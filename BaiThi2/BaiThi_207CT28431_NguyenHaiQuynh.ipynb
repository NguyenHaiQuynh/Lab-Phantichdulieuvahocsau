# %%
# Họ và Tên: Nguyễn Hải Quỳnh
# MSSV: 207CT28431

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
import numpy as np
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Bước 1: Load data
def load_dataset():
    X, y = load_iris(return_X_y=True)
    X = X[y!=2]
    y = y[y!=2]
    return X,y
#Điền ở đây
X, y = load_dataset()
print(X.shape, y.shape)
# Out:
# (100, 4) (100,)

# %% [markdown]
# Kết quả: (100, 4) (100,)

# %%
#Trực quan hóa dữ liệu data
#Điền code ở đây
plt.scatter(X[:, 0], X[:, 1], c=y, cmap='viridis')
plt.xlabel('')
plt.ylabel('')
plt.show()

# %% [markdown]
# Kết quả

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Bước 2: Định nghĩa mô hình hồi quy logistic bằng PyTorch
class LogisticRegressTorch(nn.Module):
    def __init__(self, n_features):
        super(LogisticRegressTorch, self).__init__()
        self.linear = nn.Linear(n_features, 1) # tạo một lớp tuyến tính (nn.Linear) với n_features đầu vào và 1 đầu ra

    def forward(self, x):
        return torch.sigmoid(self.linear(x))

# %%
# Bước 3: Định nghĩa lớp dữ liệu
class IrisTorch(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X, dtype=torch.float32)
        self.y = torch.tensor(y, dtype=torch.float32).unsqueeze(1)

    def __len__(self):
        return len(self.X)  #trả về số lượng mẫu trong tập dữ liệu (số lượng hàng trong self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]  #trả về một cặp đặc trưng và nhãn tương ứng với chỉ số idx

# %%
# Tạo dữ liệu
dataset = IrisTorch(X, y)

# %%
# Bước 4: Chia tập dữ liệu thành tập huấn luyện và tập kiểm tra bằng cách chia ngẫu nhiên 70,30.
train_size = int(0.7 * len(dataset))  # 70%
test_size = len(dataset) - train_size  # 30%
train_dataset, test_dataset = random_split(dataset, [train_size, test_size])

# %%
# Tạo DataLoader
batch_size = 64
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
# Bước 5: Định nghĩa criterion và optimizer
n_features = X.shape[1]
n_classes = 1
model = torch.nn.Linear(n_features, n_classes)
criterion = torch.nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.01)

# %%
# Huấn luyện mô hình
n_epochs = 100
train_losses = []
test_losses = []
test_accuracies = []

for epoch in range(n_epochs):
    model.train()
    train_loss = 0.0
    for inputs, targets in train_loader:
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()
        train_loss += loss.item() * inputs.size(0)

    train_loss /= len(train_loader.dataset)
    train_losses.append(train_loss)

    # Đánh giá trên tập kiểm tra
    model.eval()
    test_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for inputs, targets in test_loader:
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            test_loss += loss.item() * inputs.size(0)

            predicted = (outputs >= 0.5).float()
            total += targets.size(0)
            correct += (predicted == targets).sum().item()

    test_loss /= len(test_loader.dataset)
    test_losses.append(test_loss)

    accuracy = correct / total
    test_accuracies.append(accuracy)

    print(f'Epoch {epoch+1}/{n_epochs}, Train Loss: {train_loss:.4f}, Test Loss: {test_loss:.4f}, Test Accuracy: {accuracy:.4f}')
# Out:
# Epoch 1/100, Train Loss: 2.2040, Test Loss: 1.0125, Test Accuracy: 0.3667
# Epoch 2/100, Train Loss: 0.8428, Test Loss: 0.4583, Test Accuracy: 0.1333
# Epoch 3/100, Train Loss: 0.5314, Test Loss: 0.4166, Test Accuracy: 0.0000
# Epoch 4/100, Train Loss: 0.4493, Test Loss: 0.6253, Test Accuracy: 0.4000
# Epoch 5/100, Train Loss: 0.4837, Test Loss: 0.3474, Test Accuracy: 0.6000
# Epoch 6/100, Train Loss: 0.4728, Test Loss: 0.2466, Test Accuracy: 0.6000
# Epoch 7/100, Train Loss: 0.2754, Test Loss: 0.2682, Test Accuracy: 0.4333
# Epoch 8/100, Train Loss: 0.2400, Test Loss: 0.2319, Test Accuracy: 0.5333
# Epoch 9/100, Train Loss: 0.2003, Test Loss: 0.1647, Test Accuracy: 0.6000
# Epoch 10/100, Train Loss: 0.1994, Test Loss: 0.1460, Test Accuracy: 0.9333
# Epoch 11/100, Train Loss: 0.1423, Test Loss: 0.1262, Test Accuracy: 0.9667
# Epoch 12/100, Train Loss: 0.1218, Test Loss: 0.1100, Test Accuracy: 1.0000
# Epoch 13/100, Train Loss: 0.1049, Test Loss: 0.0962, Test Accuracy: 1.0000
# Epoch 14/100, Train Loss: 0.0892, Test Loss: 0.1086, Test Accuracy: 1.0000
# Epoch 15/100, Train Loss: 0.0780, Test Loss: 0.0750, Test Accuracy: 1.0000
# Epoch 16/100, Train Loss: 0.0759, Test Loss: 0.1303, Test Accuracy: 0.8667
# Epoch 17/100, Train Loss: 0.0807, Test Loss: 0.0637, Test Accuracy: 1.0000
# Epoch 18/100, Train Loss: 0.0499, Test Loss: 0.0678, Test Accuracy: 1.0000
# Epoch 19/100, Train Loss: 0.0442, Test Loss: 0.0495, Test Accuracy: 1.0000
# Epoch 20/100, Train Loss: 0.0435, Test Loss: 0.0464, Test Accuracy: 1.0000
# Epoch 21/100, Train Loss: 0.0353, Test Loss: 0.0446, Test Accuracy: 1.0000
# Epoch 22/100, Train Loss: 0.0303, Test Loss: 0.0384, Test Accuracy: 1.0000
# Epoch 23/100, Train Loss: 0.0331, Test Loss: 0.0413, Test Accuracy: 1.0000
# Epoch 24/100, Train Loss: 0.0238, Test Loss: 0.0338, Test Accuracy: 1.0000
# Epoch 25/100, Train Loss: 0.0233, Test Loss: 0.0318, Test Accuracy: 1.0000
# Epoch 26/100, Train Loss: 0.0206, Test Loss: 0.0331, Test Accuracy: 1.0000
# Epoch 27/100, Train Loss: 0.0179, Test Loss: 0.0328, Test Accuracy: 1.0000
# Epoch 28/100, Train Loss: 0.0167, Test Loss: 0.0345, Test Accuracy: 1.0000
# Epoch 29/100, Train Loss: 0.0161, Test Loss: 0.0279, Test Accuracy: 1.0000
# Epoch 30/100, Train Loss: 0.0143, Test Loss: 0.0301, Test Accuracy: 1.0000
# Epoch 31/100, Train Loss: 0.0138, Test Loss: 0.0315, Test Accuracy: 1.0000
# Epoch 32/100, Train Loss: 0.0138, Test Loss: 0.0257, Test Accuracy: 1.0000
# Epoch 33/100, Train Loss: 0.0125, Test Loss: 0.0217, Test Accuracy: 1.0000
# Epoch 34/100, Train Loss: 0.0151, Test Loss: 0.0226, Test Accuracy: 1.0000
# Epoch 35/100, Train Loss: 0.0117, Test Loss: 0.0212, Test Accuracy: 1.0000
# Epoch 36/100, Train Loss: 0.0114, Test Loss: 0.0226, Test Accuracy: 1.0000
# Epoch 37/100, Train Loss: 0.0105, Test Loss: 0.0248, Test Accuracy: 1.0000
# Epoch 38/100, Train Loss: 0.0108, Test Loss: 0.0295, Test Accuracy: 1.0000
# Epoch 39/100, Train Loss: 0.0123, Test Loss: 0.0240, Test Accuracy: 1.0000
# Epoch 40/100, Train Loss: 0.0103, Test Loss: 0.0217, Test Accuracy: 1.0000
# Epoch 41/100, Train Loss: 0.0101, Test Loss: 0.0277, Test Accuracy: 1.0000
# Epoch 42/100, Train Loss: 0.0114, Test Loss: 0.0212, Test Accuracy: 1.0000
# Epoch 43/100, Train Loss: 0.0101, Test Loss: 0.0264, Test Accuracy: 1.0000
# Epoch 44/100, Train Loss: 0.0114, Test Loss: 0.0321, Test Accuracy: 1.0000
# Epoch 45/100, Train Loss: 0.0135, Test Loss: 0.0215, Test Accuracy: 1.0000
# Epoch 46/100, Train Loss: 0.0098, Test Loss: 0.0327, Test Accuracy: 1.0000
# Epoch 47/100, Train Loss: 0.0149, Test Loss: 0.0370, Test Accuracy: 1.0000
# Epoch 48/100, Train Loss: 0.0154, Test Loss: 0.0179, Test Accuracy: 1.0000
# Epoch 49/100, Train Loss: 0.0117, Test Loss: 0.0193, Test Accuracy: 1.0000
# Epoch 50/100, Train Loss: 0.0097, Test Loss: 0.0184, Test Accuracy: 1.0000
# Epoch 51/100, Train Loss: 0.0102, Test Loss: 0.0175, Test Accuracy: 1.0000
# Epoch 52/100, Train Loss: 0.0114, Test Loss: 0.0312, Test Accuracy: 1.0000
# Epoch 53/100, Train Loss: 0.0133, Test Loss: 0.0198, Test Accuracy: 1.0000
# Epoch 54/100, Train Loss: 0.0093, Test Loss: 0.0173, Test Accuracy: 1.0000
# Epoch 55/100, Train Loss: 0.0102, Test Loss: 0.0253, Test Accuracy: 1.0000
# Epoch 56/100, Train Loss: 0.0106, Test Loss: 0.0203, Test Accuracy: 1.0000
# Epoch 57/100, Train Loss: 0.0092, Test Loss: 0.0225, Test Accuracy: 1.0000
# Epoch 58/100, Train Loss: 0.0095, Test Loss: 0.0170, Test Accuracy: 1.0000
# Epoch 59/100, Train Loss: 0.0102, Test Loss: 0.0213, Test Accuracy: 1.0000
# Epoch 60/100, Train Loss: 0.0094, Test Loss: 0.0208, Test Accuracy: 1.0000
# Epoch 61/100, Train Loss: 0.0092, Test Loss: 0.0171, Test Accuracy: 1.0000
# Epoch 62/100, Train Loss: 0.0100, Test Loss: 0.0315, Test Accuracy: 1.0000
# Epoch 63/100, Train Loss: 0.0137, Test Loss: 0.0209, Test Accuracy: 1.0000
# Epoch 64/100, Train Loss: 0.0092, Test Loss: 0.0188, Test Accuracy: 1.0000
# Epoch 65/100, Train Loss: 0.0093, Test Loss: 0.0172, Test Accuracy: 1.0000
# Epoch 66/100, Train Loss: 0.0112, Test Loss: 0.0176, Test Accuracy: 1.0000
# Epoch 67/100, Train Loss: 0.0097, Test Loss: 0.0211, Test Accuracy: 1.0000
# Epoch 68/100, Train Loss: 0.0094, Test Loss: 0.0247, Test Accuracy: 1.0000
# Epoch 69/100, Train Loss: 0.0103, Test Loss: 0.0198, Test Accuracy: 1.0000
# Epoch 70/100, Train Loss: 0.0092, Test Loss: 0.0357, Test Accuracy: 1.0000
# Epoch 71/100, Train Loss: 0.0166, Test Loss: 0.0262, Test Accuracy: 1.0000
# Epoch 72/100, Train Loss: 0.0113, Test Loss: 0.0221, Test Accuracy: 1.0000
# Epoch 73/100, Train Loss: 0.0094, Test Loss: 0.0164, Test Accuracy: 1.0000
# Epoch 74/100, Train Loss: 0.0109, Test Loss: 0.0197, Test Accuracy: 1.0000
# Epoch 75/100, Train Loss: 0.0090, Test Loss: 0.0208, Test Accuracy: 1.0000
# Epoch 76/100, Train Loss: 0.0093, Test Loss: 0.0244, Test Accuracy: 1.0000
# Epoch 77/100, Train Loss: 0.0104, Test Loss: 0.0188, Test Accuracy: 1.0000
# Epoch 78/100, Train Loss: 0.0089, Test Loss: 0.0187, Test Accuracy: 1.0000
# Epoch 79/100, Train Loss: 0.0091, Test Loss: 0.0346, Test Accuracy: 1.0000
# Epoch 80/100, Train Loss: 0.0146, Test Loss: 0.0182, Test Accuracy: 1.0000
# Epoch 81/100, Train Loss: 0.0174, Test Loss: 0.0195, Test Accuracy: 1.0000
# Epoch 82/100, Train Loss: 0.0089, Test Loss: 0.0161, Test Accuracy: 1.0000
# Epoch 83/100, Train Loss: 0.0121, Test Loss: 0.0160, Test Accuracy: 1.0000
# Epoch 84/100, Train Loss: 0.0109, Test Loss: 0.0259, Test Accuracy: 1.0000
# Epoch 85/100, Train Loss: 0.0110, Test Loss: 0.0167, Test Accuracy: 1.0000
# Epoch 86/100, Train Loss: 0.0093, Test Loss: 0.0199, Test Accuracy: 1.0000
# Epoch 87/100, Train Loss: 0.0090, Test Loss: 0.0165, Test Accuracy: 1.0000
# Epoch 88/100, Train Loss: 0.0135, Test Loss: 0.0231, Test Accuracy: 1.0000
# Epoch 89/100, Train Loss: 0.0099, Test Loss: 0.0166, Test Accuracy: 1.0000
# Epoch 90/100, Train Loss: 0.0094, Test Loss: 0.0172, Test Accuracy: 1.0000
# Epoch 91/100, Train Loss: 0.0090, Test Loss: 0.0182, Test Accuracy: 1.0000
# Epoch 92/100, Train Loss: 0.0088, Test Loss: 0.0184, Test Accuracy: 1.0000
# Epoch 93/100, Train Loss: 0.0088, Test Loss: 0.0194, Test Accuracy: 1.0000
# Epoch 94/100, Train Loss: 0.0089, Test Loss: 0.0200, Test Accuracy: 1.0000
# Epoch 95/100, Train Loss: 0.0089, Test Loss: 0.0162, Test Accuracy: 1.0000
# Epoch 96/100, Train Loss: 0.0101, Test Loss: 0.0196, Test Accuracy: 1.0000
# Epoch 97/100, Train Loss: 0.0090, Test Loss: 0.0286, Test Accuracy: 1.0000
# Epoch 98/100, Train Loss: 0.0123, Test Loss: 0.0192, Test Accuracy: 1.0000
# Epoch 99/100, Train Loss: 0.0088, Test Loss: 0.0164, Test Accuracy: 1.0000
# Epoch 100/100, Train Loss: 0.0101, Test Loss: 0.0164, Test Accuracy: 1.0000

# %%
# Vẽ biểu đồ loss và accuracy
# %matplotlib inline
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(train_losses, label='Train Loss')
plt.plot(test_losses, label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(test_accuracies, label='Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %% [markdown]
# #Kết quả:

# %% [markdown]
# ![image.png](attachment:image.png)
